# %% [markdown]
# Q1. Load the given Customer.csv in the Databricks which has first row as a header and display the 50 rows.
#
# Q2. Load the given Product_without_header.csv in the Databricks which has no header, assign the schema as follow to it and display the 50 rows.
#
# ProductID:integer
# Name:string
# ProductNumber:string
# Color:string
# StandardCost:double
# ListPrice:double
# Size:string
# Weight:double
# ProductCategoryID:integer
# ProductModelID:integer
# SellStartDate:timestamp
# SellEndDate:timestamp
# DiscontinuedDate:string
# ThumbNailPhoto:string
# ThumbnailPhotoFileName:string
# rowguid:string
# ModifiedDate:timestamp
#
#
#
# Q3. Load the given Customer_Address.csv in the Databricks which has first row as a header & column seperator as 'I'
#     and display the 50 rows.
#
# Q4. Load the Address.json  file in the Databricks and display the schema of the it.
#
# Q5. Create a dataframe manually with having three rows & 2 column as follows
#
# ID	Order_status
# 1	Booked
# 2	In Transit
# 3	Delivered
#
# Q6. Display all the Customer having title has 'Mr'
#
# Q7. Display all the Productid having the product color as 'Black'
#
# Q8. Find and display all the distinct color of the products.
#
# Q9. Load the data from this second_Product.csv and display all the product combining the previous product dataframe.
#
# Q10. Display all the product from both the product dataframe together without any duplication.
#
# Q11. Remove all the records from the customer having customer id null and display the count of null records.
#
# Q12. Display the product name and product list price as a single column seperated by '----'
#
# Q13. There are many records in the product table having the weight has null, fill all those null values with default weight = 100.
#
# Q14. Find all the product which are having list price more than 50 and Red in color. Display the result in the descending Productid
#
# Q15. Find out year for every product in which it has been registered along with product id.
#
# Q16. Add a new column in the Customer table as 'Databricks_Entry_Date' and assign the value as current_date.
